# %% [markdown]
# <a href="https://colab.research.google.com/github/Ryukocharm/Tesi/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -q immagini-galassie.zip -d immagini-galassie

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import numpy as np
import os, random #os serve per comunicare con il sistema operativo
from skimage import io
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras import layers
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers, optimizers

# %%
# mostra le immagini
plt.figure(figsize=(12,12))
root = "immagini-galassie"
for i in range(25):
  filename = random.choice(os.listdir(f"{root}")) #selezione casuale di file
  path = f"{root}/{filename}" #percorso finale
  img = mpimg.imread(path) #leggiamo l'immagine dal path con matplotlib
  plt.subplot(5, 5, i + 1)
  plt.imshow(img)
  plt.axis("off")
  plt.title(filename)
plt.show()

# %%
dataframe = pd.read_csv(filepath_or_buffer = "dataframe.csv",
                       sep=",",
                       header=0,
                       usecols = ["file_path", "logfgas"],
                       )

dataframe
# Out:
#                                      file_path  logfgas
# 0     /content/immagini-galassie/ACG331061.jpg -0.44736
# 1     /content/immagini-galassie/ACG101869.jpg -0.35081
# 2     /content/immagini-galassie/ACG331082.jpg  0.10447
# 3     /content/immagini-galassie/ACG101873.jpg -0.15395
# 4     /content/immagini-galassie/ACG101877.jpg  0.89593
# ...                                        ...      ...
# 5020  /content/immagini-galassie/ACG332876.jpg  1.53828
# 5021  /content/immagini-galassie/ACG332880.jpg  0.05066
# 5022  /content/immagini-galassie/ACG332881.jpg  0.47444
# 5023  /content/immagini-galassie/ACG332884.jpg -0.01308
# 5024  /content/immagini-galassie/ACG332887.jpg  0.90231
#
# [5025 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X = dataframe['file_path']
y = dataframe['logfgas']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
X_test
# Out:
# 408     /content/immagini-galassie/ACG182478.jpg
# 4335    /content/immagini-galassie/ACG252014.jpg
# 1722    /content/immagini-galassie/ACG214280.jpg
# 2347    /content/immagini-galassie/ACG224231.jpg
# 1051    /content/immagini-galassie/ACG205138.jpg
#                           ...
# 3774    /content/immagini-galassie/ACG726428.jpg
# 2939    /content/immagini-galassie/ACG238731.jpg
# 1035    /content/immagini-galassie/ACG715627.jpg
# 4393    /content/immagini-galassie/ACG252278.jpg
# 199     /content/immagini-galassie/ACG188850.jpg
# Name: file_path, Length: 1005, dtype: object

# %%
len(X_train)
# Out:
# 4020

# %%
len(X_test)
# Out:
# 1005

# %%
test_dataframe = pd.concat([X_test, y_test], axis=1)

test_dataframe
# Out:
#                                      file_path  logfgas
# 408   /content/immagini-galassie/ACG182478.jpg  0.97107
# 4335  /content/immagini-galassie/ACG252014.jpg -0.14933
# 1722  /content/immagini-galassie/ACG214280.jpg  0.58832
# 2347  /content/immagini-galassie/ACG224231.jpg  0.04119
# 1051  /content/immagini-galassie/ACG205138.jpg  0.36776
# ...                                        ...      ...
# 3774  /content/immagini-galassie/ACG726428.jpg  0.40307
# 2939  /content/immagini-galassie/ACG238731.jpg  0.59806
# 1035  /content/immagini-galassie/ACG715627.jpg -0.13203
# 4393  /content/immagini-galassie/ACG252278.jpg -0.63547
# 199   /content/immagini-galassie/ACG188850.jpg  0.38587
#
# [1005 rows x 2 columns]

# %%
train_dataframe = pd.concat([X_train, y_train], axis=1)

train_dataframe
# Out:
#                                      file_path  logfgas
# 1734    /content/immagini-galassie/ACG6321.jpg -0.29854
# 3485  /content/immagini-galassie/ACG249090.jpg  0.24403
# 1569  /content/immagini-galassie/ACG212010.jpg -0.70223
# 3658  /content/immagini-galassie/ACG243979.jpg  0.40448
# 2528  /content/immagini-galassie/ACG226070.jpg  0.35151
# ...                                        ...      ...
# 1712  /content/immagini-galassie/ACG212133.jpg -0.01922
# 1127  /content/immagini-galassie/ACG200365.jpg -0.41139
# 1408  /content/immagini-galassie/ACG200645.jpg -0.63310
# 5010  /content/immagini-galassie/ACG330784.jpg -0.47529
# 2573  /content/immagini-galassie/ACG220555.jpg  0.22818
#
# [4020 rows x 2 columns]

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=(0.8,0.8),
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=5,
    validation_split=0.2)

test_datagen = ImageDataGenerator(
    rescale=1./255)

# %%
train_generator = datagen.flow_from_dataframe(
    dataframe=train_dataframe,
    x_col="file_path",
    y_col="logfgas",
    class_mode="raw",
    target_size=(256, 256),
    color_mode='rgb',
    batch_size=32,
    shuffle=False,
    seed=42,
    subset='training')

val_generator = datagen.flow_from_dataframe(
    dataframe=train_dataframe,
    x_col="file_path",
    y_col="logfgas",
    class_mode="raw",
    target_size=(256, 256),
    color_mode='rgb',
    batch_size=32,
    shuffle=False,
    seed=42,
    subset='validation')

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_dataframe,
    x_col="file_path",
    y_col="logfgas",
    class_mode="raw",
    target_size=(256, 256),
    color_mode='rgb',
    batch_size=1,
    shuffle=False)
# Out:
# Found 3216 validated image filenames.
# Found 804 validated image filenames.
# Found 1005 validated image filenames.

# %%
net_model2 = tf.keras.Sequential()

net_model2.add(layers.Conv2D(32, 3, input_shape=(256, 256, 3), activation="relu"))
net_model2.add(layers.MaxPooling2D())

net_model2.add(layers.Conv2D(64, 5, activation="relu"))
net_model2.add(layers.MaxPooling2D())
net_model2.add(layers.Dropout(0.4))

net_model2.add(layers.Conv2D(32, 3, activation="relu"))
net_model2.add(layers.MaxPooling2D())
net_model2.add(layers.Dropout(0.2))

net_model2.add(layers.Flatten())
net_model2.add(layers.Dense(1, activation="linear"))

# %%
net_model2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='mae'
)

# %%
training = net_model2.fit(
    train_generator,
    validation_data=val_generator,
    batch_size= 100,
    epochs=10)
# Out:
# Epoch 1/10
# 101/101 [==============================] - 67s 648ms/step - loss: 0.3327 - val_loss: 0.3428
# Epoch 2/10
# 101/101 [==============================] - 63s 625ms/step - loss: 0.2357 - val_loss: 0.3122
# Epoch 3/10
# 101/101 [==============================] - 67s 663ms/step - loss: 0.2240 - val_loss: 0.2475
# Epoch 4/10
# 101/101 [==============================] - 63s 628ms/step - loss: 0.2146 - val_loss: 0.2394
# Epoch 5/10
# 101/101 [==============================] - 65s 644ms/step - loss: 0.2207 - val_loss: 0.2561
# Epoch 6/10
# 101/101 [==============================] - 63s 623ms/step - loss: 0.2133 - val_loss: 0.2313
# Epoch 7/10
# 101/101 [==============================] - 63s 625ms/step - loss: 0.2036 - val_loss: 0.2501
# Epoch 8/10
# 101/101 [==============================] - 64s 631ms/step - loss: 0.2039 - val_loss: 0.2324
# Epoch 9/10
# 101/101 [==============================] - 63s 621ms/step - loss: 0.1993 - val_loss: 0.2435
# Epoch 10/10
# 101/101 [==============================] - 63s 624ms/step - loss: 0.2048 - val_loss: 0.2368

# %%
def plot_loss(history):
  plt.title("Mean Absolute Error")
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  plt.ylim([0, 1])
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend()
  plt.grid(True)

# %%
plot_loss(training)

# %%
net_model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 254, 254, 32)      896
#
#  max_pooling2d_8 (MaxPoolin  (None, 127, 127, 32)      0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 123, 123, 64)      51264
#
#  max_pooling2d_9 (MaxPoolin  (None, 61, 61, 64)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 61, 61, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 59, 59, 32)        18464
#
#  max_pooling2d_10 (MaxPooli  (None, 29, 29, 32)        0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 27, 27, 32)        9248
#
#  max_pooling2d_11 (MaxPooli  (None, 13, 13, 32)        0
#  ng2D)
#
#  dropout_5 (Dropout)         (None, 13, 13, 32)        0
#
#  flatten_2 (Flatten)         (None, 5408)              0
#
#  dense_2 (Dense)             (None, 1)                 5409
#
# =================================================================
# Total params: 85281 (333.13 KB)
# Trainable params: 85281 (333.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
testing = net_model2.predict(test_generator)
testing
# Out:
# 1005/1005 [==============================] - 5s 5ms/step
# array([[ 0.69290954],
#        [ 0.11756106],
#        [ 0.54753065],
#        ...,
#        [ 0.2648813 ],
#        [-0.10224931],
#        [ 0.52704096]], dtype=float32)

# %%
test_dataframe
# Out:
#                                      file_path  logfgas
# 408   /content/immagini-galassie/ACG182478.jpg  0.97107
# 4335  /content/immagini-galassie/ACG252014.jpg -0.14933
# 1722  /content/immagini-galassie/ACG214280.jpg  0.58832
# 2347  /content/immagini-galassie/ACG224231.jpg  0.04119
# 1051  /content/immagini-galassie/ACG205138.jpg  0.36776
# ...                                        ...      ...
# 3774  /content/immagini-galassie/ACG726428.jpg  0.40307
# 2939  /content/immagini-galassie/ACG238731.jpg  0.59806
# 1035  /content/immagini-galassie/ACG715627.jpg -0.13203
# 4393  /content/immagini-galassie/ACG252278.jpg -0.63547
# 199   /content/immagini-galassie/ACG188850.jpg  0.38587
#
# [1005 rows x 2 columns]

# %%
x_line = y_test
y_line = x_line
plt.plot(x_line, y_line, color='k')

plt.scatter(y_test, testing)
